# %%
import numpy as np
import seaborn as sns
from scipy.special import polygamma

# %%
a = np.random.gamma(100, 1, 10000)
b = np.log(a)

# %%
np.var(b)
# Out:
# np.float64(0.010079377885994468)

# %%
polygamma(1, 1)
# Out:
# array(1.64493407)

# %%
x = np.linspace(0.01, 0.05, 200)
y = np.array([(1 / x)**2 for x in x])
sns.scatterplot(x=x, y=y)

x = np.linspace(0.01, 0.05, 100)
y = np.array([polygamma(1, x) for x in x])
sns.scatterplot(x=x, y=y)
# Out:
# <Axes: >

# %%
polygamma(1, 37)
# Out:
# array(0.02739555)

# %%
(1 / 0.027)**2
# Out:
# 1371.7421124828534
